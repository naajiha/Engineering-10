# %% [markdown]
# <h2 style="text-align:center"><strong>Weekly Assignment 3: Driveway Cost Table</strong></h2>

# %% [markdown]
# The boss would like me to create a table that has the row header as width and the column header as length. The row header will range from 10 feet to 24 feet with increments on 2 feet in-between each width amount leading to a total of 8 width lengths. The column header will range from 10 feet to 30 feet with a 1 foot in-between each length amount leading to a total of 20 column lengths. Then he would like me to program a table that takes the dimension of length * width for any of the combinations of length and width, to produce a price of the driveway for customers to use.
#
# I will begin planning to do it by creating pseudocode on a scratch paper laying out the possible python techniques I can use to create this table. I can use for loops that add the increments combined with arrays in order to create the table itself. I will pull code from the last project my boss assigned me as I already have a method for calculating the amount of concrete mix needed

# %% [markdown]
# For this section I will first create a for loop bounding my lengths with increments of one. I will set width to 10 since it will not vary. Then I will create an equation that calculates the costs for lengths 10 through 30 and print two columns next to each other.

# %%
width = 10 #here I am setting width to a set value
for length in range(10,31): #here I am setting length with increments of 1
    if width == 10: 
        #here I am calculating the number of bags needed for the driveway
        numBags = ((length * 10 * (4/12) * 1.1)/ (2*2*(4/12))) 
        #here I am calculating the cost for the driveway
        cost = round(4.27 * numBags) 
        print(length, '$', round(cost, 2))
# Out:
# 10 $ 117
# 11 $ 129
# 12 $ 141
# 13 $ 153
# 14 $ 164
# 15 $ 176
# 16 $ 188
# 17 $ 200
# 18 $ 211
# 19 $ 223
# 20 $ 235
# 21 $ 247
# 22 $ 258
# 23 $ 270
# 24 $ 282
# 25 $ 294
# 26 $ 305
# 27 $ 317
# 28 $ 329
# 29 $ 341
# 30 $ 352

# %% [markdown]
# I pulled the loop from the previous step to process length from length 10 to 31. This I will make a for loop for width, then once again I will calculate the costs for the number of bags used.

# %%
print("Length                          Width")
print('           10      12      14      16      18      20      22      24')
print("                                 Cost")
#the unit volume is 2 feet squared times (4/12)
for length in range(10,31):
    print(length, end = '    ')
    for width in range(10, 25, 2):
        numBags = ((length * width * (4/12) * 1.1)/ (2*2*(4/12)))
        cost = round(4.27 * numBags)
        #check the round sign some values print one zero
    
        print("\t", "$", cost, end="") #here I tabbed the text for cleaner results
    print() #this prints my results in one line of text
# Out:
# Length                          Width
#            10      12      14      16      18      20      22      24
#                                  Cost
# 10    	 $ 117	 $ 141	 $ 164	 $ 188	 $ 211	 $ 235	 $ 258	 $ 282
# 11    	 $ 129	 $ 155	 $ 181	 $ 207	 $ 233	 $ 258	 $ 284	 $ 310
# 12    	 $ 141	 $ 169	 $ 197	 $ 225	 $ 254	 $ 282	 $ 310	 $ 338
# 13    	 $ 153	 $ 183	 $ 214	 $ 244	 $ 275	 $ 305	 $ 336	 $ 366
# 14    	 $ 164	 $ 197	 $ 230	 $ 263	 $ 296	 $ 329	 $ 362	 $ 395
# 15    	 $ 176	 $ 211	 $ 247	 $ 282	 $ 317	 $ 352	 $ 388	 $ 423
# 16    	 $ 188	 $ 225	 $ 263	 $ 301	 $ 338	 $ 376	 $ 413	 $ 451
# 17    	 $ 200	 $ 240	 $ 279	 $ 319	 $ 359	 $ 399	 $ 439	 $ 479
# 18    	 $ 211	 $ 254	 $ 296	 $ 338	 $ 380	 $ 423	 $ 465	 $ 507
# 19    	 $ 223	 $ 268	 $ 312	 $ 357	 $ 402	 $ 446	 $ 491	 $ 535
# 20    	 $ 235	 $ 282	 $ 329	 $ 376	 $ 423	 $ 470	 $ 517	 $ 564
# 21    	 $ 247	 $ 296	 $ 345	 $ 395	 $ 444	 $ 493	 $ 543	 $ 592
# 22    	 $ 258	 $ 310	 $ 362	 $ 413	 $ 465	 $ 517	 $ 568	 $ 620
# ...

# %% [markdown]
# Here I will create two lists, drivewayData, my overall structure and cost. I will then append both of them to create the larger structure. Costs will have sublists width and length appended to it.

# %%
drivewayData = [] #creating overall structure
for length in range(10, 32): #creating length loop list
    for width in range(10, 26, 2): #creating width loop list
        cost = [] #creating empty cost list
        cost.append(width) #putting width into cost
        cost.append(length) #putting length into cost
        numBags = ((length * width * (4/12) * 1.1)/ (2*2*(4/12)))
        price = round(4.27 * numBags)
        cost.append(price)
        drivewayData.append(cost) #putting cost into drivewayLength
print(drivewayData)
# Out:
# [[10, 10, 117], [12, 10, 141], [14, 10, 164], [16, 10, 188], [18, 10, 211], [20, 10, 235], [22, 10, 258], [24, 10, 282], [10, 11, 129], [12, 11, 155], [14, 11, 181], [16, 11, 207], [18, 11, 233], [20, 11, 258], [22, 11, 284], [24, 11, 310], [10, 12, 141], [12, 12, 169], [14, 12, 197], [16, 12, 225], [18, 12, 254], [20, 12, 282], [22, 12, 310], [24, 12, 338], [10, 13, 153], [12, 13, 183], [14, 13, 214], [16, 13, 244], [18, 13, 275], [20, 13, 305], [22, 13, 336], [24, 13, 366], [10, 14, 164], [12, 14, 197], [14, 14, 230], [16, 14, 263], [18, 14, 296], [20, 14, 329], [22, 14, 362], [24, 14, 395], [10, 15, 176], [12, 15, 211], [14, 15, 247], [16, 15, 282], [18, 15, 317], [20, 15, 352], [22, 15, 388], [24, 15, 423], [10, 16, 188], [12, 16, 225], [14, 16, 263], [16, 16, 301], [18, 16, 338], [20, 16, 376], [22, 16, 413], [24, 16, 451], [10, 17, 200], [12, 17, 240], [14, 17, 279], [16, 17, 319], [18, 17, 359], [20, 17, 399], [22, 17, 439], [24, 17, 479], [10, 18, 211], [12, 18, 254], [14, 18
# ...

# %% [markdown]
# I will create an if statement for smallest and largest. I will create if statements for smallest and largest amount of money used.If it is small I will display how much money the customer needs. If they have more money than needed then it prints money leftover. If it is the in-between amount I will use a for loop wrapped around if statements to scan the data structure for driveway and money left over.

# %%
#  In this cell, test the case with a budget too small to afford any driveway
print('please enter your budget')
budget = float(input())
if budget < 117:
    print('Your budget is too small to afford any driveway, you need $', 213.5 - budget, "to afford this 10' x 10' x (4/12)' driveway")
# Out:
# please enter your budget
# 7
# Your budget is too small to afford any driveway, you need $ 206.5 to afford this 10' x 10' x (4/12)' driveway

# %%
#  In this cell, test the case with a budget large enough to afford any size driveway
print('please enter your budget')
budget = float(input())
if budget >= 874:
    print('Your budget is big enough to afford the biggest driveway, you will have $', budget - 874, "left over for this 10' x 30' x (4/12)'")
# Out:
# please enter your budget
# 9000
# Your budget is big enough to afford the biggest driveway, you will have $ 8126.0 left over for this 10' x 30' x (4/12)'

# %%
#   In this cell, test the case with a budget that can only afford a driveway somewhere in the middle of the table
print("Enter budget")
budget = float(input())
drivewayLength = 0
maxCost = 0

for i in range(0, 21):
    if budget >= drivewayData[i][0]:
        maxCost = drivewayData[i][0]
        drivewayLength = length + 10
    if i == 20:
        leftover =  budget - maxCost
        
        if maxCost > 0 and maxCost <= drivewayData[i][0]:
            print("You can afford a driveway with a width of 10 feet and a length of", drivewayLength, "feet. You have $", leftover, "left")
        if maxCost == 0:
            moneyRequired = drivewayData[0][0] - round(budget, 2)
            print("You do not have enough money. $", moneyRequired, "in order to afford the cheapest driveway of", drivewayLength)
        if maxCost == drivewayData[i][0] and budget > 0:
            print("You can afford the driveway with width of 10 feet and a length of", drivewayLength, "you have $", maxCost - budget, "after buying the driveway")
# Out:
# Enter budget
# 900
# You can afford a driveway with a width of 10 feet and a length of 41 feet. You have $ 882.0 left
# You can afford the driveway with width of 10 feet and a length of 41 you have $ -882.0 after buying the driveway

# %% [markdown]
# In the boss's assignment I first created a program that displayed driveway costs with a set width of 10 and varying lengths from 10 feet to 30 feet. Then I created a program that would tell the price for the driveway with varying lengths and widths.Then I created a sort of memory bank for all the driveway length, width, and cost values as a memory storage. Then I created a program that could tell customers how much money they needed to afford a driveway if they had too little. How much they'd have leftover if they had too much money. And how much they could afford if they had a budget between the smallest and largest driveway costs.
